# %% [markdown]
# <a href="https://colab.research.google.com/github/rajatpal00/Yes-Bank-Stock-price-/blob/main/Rajat_Pal_Yes_Bank_stock_price_prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Yes Bank prediction Model**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df= pd.read_csv('/content/drive/MyDrive/AlmaBetter/capstone project/Yes bank share price/Copy of data_YesBank_StockPrices.csv')

# %%
data_df
# Out:
#        Date   Open   High    Low  Close
# 0    Jul-05  13.00  14.00  11.25  12.46
# 1    Aug-05  12.58  14.88  12.55  13.42
# 2    Sep-05  13.48  14.87  12.27  13.30
# 3    Oct-05  13.20  14.47  12.40  12.99
# 4    Nov-05  13.35  13.88  12.88  13.41
# ..      ...    ...    ...    ...    ...
# 180  Jul-20  25.60  28.30  11.10  11.95
# 181  Aug-20  12.00  17.16  11.85  14.37
# 182  Sep-20  14.30  15.34  12.75  13.15
# 183  Oct-20  13.30  14.01  12.11  12.42
# 184  Nov-20  12.41  14.90  12.21  14.67
#
# [185 rows x 5 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %% [markdown]
# So with the help of .info(), we found there is no full value present in data set

# %%
#lets find how data is distributed with describe
data_df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# With the help of describe we can conclude that data is not normally distributed as mean is higher than median in all features

# %% [markdown]
# #### Visualization of Data

# %%
# line plot 
plt.figure(figsize=(20,10))
sns.lineplot(x= data_df['Date'],y = data_df['High'],label='High')
sns.lineplot(x= data_df['Date'],y = data_df['Close'],label ='Close')
sns.lineplot(x= data_df['Date'],y = data_df['Open'],label= 'Open')
sns.lineplot(x= data_df['Date'],y = data_df['Low'],label ='Low')
sns.set_style("darkgrid")
